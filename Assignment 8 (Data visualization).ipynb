# %% [markdown]
# 1.In this assignment students have to transform iris data into 3 dimensions and plot a 3d chart with transformed dimensions and colour each data point with specific class.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn import decomposition
from sklearn import datasets

# %%
import seaborn as sns

# %%
df=sns.load_dataset('iris')
df.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa

# %%
df.plot()

# %%
from mpl_toolkits.mplot3d import Axes3D as ax

# %%
ax=plt.axes(projection='3d')
xs=range(0,9)
ys=range(0,9)
zs=range(0,9)
ax.scatter(xs,ys,zs,c='b')
ax.set_xlabel(xlabel='sepal_length')
ax.set_ylabel(ylabel='sepal_width')
ax.set_zlabel(zlabel='petal_length')
plt.cm.rainbow(9)
# Out:
# (0.4294117647058824, 0.11065268189150083, 0.9984636039674339, 1.0)
